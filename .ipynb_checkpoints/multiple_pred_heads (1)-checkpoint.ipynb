# %%
# https://shorturl.at/nyzL4
# https://shorturl.at/FO479
import gymnasium as gym
import math
import random
import copy
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
import numpy as np

import torch
import torch.nn as nn

import torch.nn.functional as F
import torch.optim as optim

import pandas as pd
import seaborn as sns; sns.set()

# %%
env = gym.make("BipedalWalker-v3") #Setting up an existing open AI gym environment
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

    plt.ion()
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # GPU acceleration

# %%
""" Represents a single transition in the environment. Used for experience replay. """
Experience = namedtuple('Experience',                                       
                        ('state', 'action', 'next_state', 'reward'))
class ReplayMemory:
    """Fixed-size memory buffer to store Experience tuples."""
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)
    
    def push(self, *args):
        self.memory.append(Experience(*args))
    
    def sample(self, batch_size):
        """ Selects a random batch of transitions for training"""
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):
    """
    Deep Q-Network model
    """
    def __init__(self, state_size, action_size, seed):
        """
        Initialize parameters and construct DQN model
        
        @param state_size(int) : Dimensions of each state
        @param action_size(int): Dimensions of each action
        @param seed            : Random seed
        """
        super(DQN, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size,64)
        self.fc2 = nn.Linear(64, 48)
        self.fc3 = nn.Linear(48, 48)
        self.fc4_1 = nn.Linear(48, action_size)
        self.fc4_2 = nn.Linear(48, action_size)
        self.fc4_3 = nn.Linear(48, action_size)
        self.fc4_4 = nn.Linear(48, action_size)
        
    def forward(self, state):
        """
        Forward propagation of the network
        
        @param state: state
        """
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        pred1 = self.fc4_1(x) # shape: (20,)
        pred2 = self.fc4_2(x)
        pred3 = self.fc4_3(x)
        pred4 = self.fc4_4(x)
        return pred1, pred2, pred3, pred4

# %%
""" Hyperparameters (Maybe receive these as arguments? (parse_args))"""
MEMORY_SIZE = int(5e4)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3
LR = 5e-4
EPSILON = 1.0
EPSILON_MIN = 0.05
EPS_DECAY = 1e-3
UPDATE_EVERY = 4

class Agent():
    """
    Agent that interacts and learns from the environment.
    Receives rewards from the environment, update DQN parameters, "memorize" experiences.
    """
    def __init__(self, state_space, action_space, disc_class, seed):
        """
        Initialize parameters and construct an Agent object
        
        @param state_size(int) : Dimensions of each state
        @param action_size(int): Dimensions of each action
        @param seed            : Random seed
        """
        self.state_space = state_space
        self.action_space = action_space
        self.disc_class = disc_class
        self.seed = random.seed(seed)
        
        # Initalize main and target DQN 
        self.main_model = DQN(state_space.shape[0], disc_class, seed).to(device)
        self.target_model = DQN(state_space.shape[0], disc_class, seed).to(device)
        self.target_model.load_state_dict(self.main_model.state_dict())
        self.target_model.eval()
        
        self.optimizer = optim.Adam(self.main_model.parameters(), lr=LR)
        
        # Replay memory
        self.memory = ReplayMemory(MEMORY_SIZE)
        
        # Initialize time step (for updating every UPDATE_EVERY step)
        self.t_step = 0
        self.eps_step = 0
        self.spacing = 0.1
    
    def add_memory(self, state, action, next_state, reward):
        # save experience in replay memory
        self.memory.push(state, action, next_state, reward)
        
    def choose_action(self, state):
        """
        Return action for given state following the current policy
        
        @param state: Current state
        @param epsilon(float)  : epsilon for epsilon-greedy action selection
        """
        eps_threshold = EPSILON_MIN + (EPSILON - EPSILON_MIN) * math.exp(-1 * self.eps_step / EPS_DECAY)
        self.eps_step += 1
        # epsilon-greedy action selection
        if random.random() > eps_threshold:
            with torch.no_grad():
                pred1, pred2, pred3, pred4 = self.main_model(state)
                pred1 = np.argmax(pred1)
                pred2 = np.argmax(pred2)
                pred3 = np.argmax(pred3)
                pred4 = np.argmax(pred4)
                action = torch.tensor((pred1, pred2, pred3, pred4))
                assert(0 <= pred1 and pred1 <= 19 and
                       0 <= pred2 and pred2 <= 19 and
                       0 <= pred3 and pred3 <= 19 and
                       0 <= pred4 and pred4 <= 19)
                # print("max:",action, action.shape)
                return action
        else:
            action = torch.randint(0, 20, (4,))
            assert(0 <= action[0] and action[0] <= 19 and
                   0 <= action[1] and action[1] <= 19 and
                   0 <= action[2] and action[2] <= 19 and
                   0 <= action[3] and action[3] <= 19)
            # print("random:", action, action.shape)
            return action
        
    def disct2cont(self,action):
        return action * self.spacing - self.action_space.high
    
    def cont2disc(self, action):
        ''' converts continuous action valeus back to indices '''
        res = [ ]
        for i in range(len(action)):
            res.append(pd.cut(action[i] , bins = np.linspace(-1.0, 1.0, num=21, endpoint = True), labels = np.arange(20), include_lowest=True, right= True))
        return res
    
    def learn(self):
        """
        Update parameters using the given batch of expreience tuples
        
        @param experiences(Tuple): tuple of (s,a,s',r) tuples
        @param gamma(float): discount factor
        """
        if len(self.memory) > BATCH_SIZE:
            experiences = self.memory.sample(BATCH_SIZE)
            batch = Experience(*zip(*experiences)) # This converts batch-array of Experiences
                                                   # to Experience of batch-arrays.
            #batch.action --> (batch_size, tensor(4,))               ==> (64, tensor(4,))
            #batch.state --> (batch_size, tensor(1,state_size))      ==> (64, tensor(1,24))
            #batch.next_state --> (batch_size, tensor(1,state_size)) ==> (64, tensor(1,24))
            #batch.reward --> (batch_size, tensor(1))                ==> (64, tensor(1))
            action_indicies = self.cont2disc(batch.action)
            action_indicies_t = torch.tensor(list(zip(*action_indicies)))   # list(4,64)
            state_batch = torch.cat(batch.state)           # tensor(64, state_size)
            next_state_batch = torch.cat(batch.next_state) # tensor(64, state_size)
            reward_batch = torch.cat(batch.reward) # shape (64, )
            rewards = reward_batch.repeat(4,1) # shape: tensor(4,64)

            self.main_model.train() # Set local network as training mode
            self.target_model.eval() # Set target network as evaluation mode

            # Compute Q(s_t, a) - the model computes Q(s_t)
            state_values = torch.stack(list(self.main_model(state_batch)), dim = 0) # changing tuple to tensor shape: tensor(4,64,20)
            state_action_values = torch.gather(state_values, 2, action_indicies_t.unsqueeze(-1)) # extracting q_values based on actions
            q_eval = torch.squeeze(state_action_values)


            # Compute V(s_{t+1}) for all next states.
            # Expected values of actions for non_final_next_states are computed based
            # on the "older" target_net; selecting their best reward with max(1)[0].
            q_next = self.target_model(next_state_batch) # shape: tuple (4, tensor(64,20))
            q_next_max = torch.zeros(4,64)
            for i in range(len(q_next_max)):
                q_next_max[i] = torch.amax(q_next[i],dim=1)
            q_target = rewards + GAMMA * q_next_max # (4,64)
            loss = F.smooth_l1_loss(q_eval, q_target)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            loss_value = float(loss.item())
            return loss_value
        
        """ UPDATE TARGET NETWORK Don't update every step (compare) """ 
        self.soft_update(self.main_model, self.target_model, TAU)
    
    def soft_update(self, main_model, target_model, tau):
        """
        θ_target = τ*θ_local + (1 - τ)*θ_target
        
        @param local_model(nn model): weights will be copied from
        @param target_model(nn model): weights will be copied to
        @param tau(float): interpolation parameter
        """
        for target_param, main_param in zip(target_model.parameters(), main_model.parameters()):
            target_param.data.copy_(tau*main_param.data + (1.0-tau)*target_param.data)

# %%
def plot_returns(returns, window=10):
    '''
    Returns (iterable): list of returns over time
    window: window for rolling mean to smooth plotted curve
    '''
    sns.lineplot(
        data=pd.DataFrame(returns).rolling(window=window).mean()[window-1::window]
    )

# %%
agent = Agent(state_space = env.observation_space, action_space = env.action_space, disc_class = 20, seed = 0)

def train(n_episodes = 10000, max_t = 1600):
    """
    Training DQN
    
    @param n_episodes(int): Number of training episodes
    @param max_t(int):      Maximum number of timesteps per episode
    eps_start(float):       Starting value of epsilon for epsilon-greedy action selection
    eps_end(float):         Minimum value of epsilon
    eps_dec(float):         Multiplicative factor for decrementing epsilon
    """
    # For plotting
    scores = [ ]
    losses = [ ]
    scores_window = deque(maxlen=100) 
    for episode in range(1,n_episodes+1):
        print('\rEpisode {}'.format(episode), end="\n")
        observation, info = env.reset()
        state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
        score = 0
        done = False
        for t in range(max_t):
            index = agent.choose_action(state)
            action = agent.disct2cont(index)
            
            next_observation, reward, done, truncated, _  = env.step(action)
            next_state = torch.tensor(next_observation, dtype=torch.float32, device=device).unsqueeze(0)
            
            reward = torch.tensor([reward],device = device)
            score += reward[0]
            agent.add_memory(state, action, next_state, reward)
            state = next_state
            
            if done:
                break
        loss = agent.learn()
        # For plotting
        losses.append(loss)
        scores_window.append(score)
        scores.append(score)
        print('\rAverage Score {:.2f}'.format(np.mean(scores_window)), end="\n")
        if score > 300:
            print(f"Environment solved! t:{t}, episode:{episode}")
            break
    return scores, losses

scores, losses = train()
plot_returns(scores)
#plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(losses)),losses)
plt.ylabel('Losses')
plt.xlabel('Epsiode #')
plt.show()
# Out:
# Episode 1
# Average Score -103.40
# Episode 2
# Average Score -104.65
# Episode 3
# Average Score -104.36
# Episode 4
# Average Score -102.05
# Episode 5
# Average Score -99.06
# Episode 6
# Average Score -94.03
# Episode 7
# Average Score -90.45
# Episode 8
# Average Score -92.11
# Episode 9
# Average Score -91.89
# Episode 10
# Average Score -93.21
# Episode 11
# Average Score -94.14
# Episode 12
# Average Score -94.41
# Episode 13
# Average Score -95.10
# Episode 14
# Average Score -97.00
# Episode 15
# Average Score -97.23
# Episode 16
# Average Score -97.93
# Episode 17
# Average Score -98.21
# Episode 18
# Average Score -96.25
# Episode 19
# Average Score -97.04
# Episode 20
# Average Score -97.77
# Episode 21
# Average Score -98.15
# Episode 22
# Average Score -98.27
# Episode 23
# Average Score -98.43
# Episode 24
# Average Score -98.90
# Episode 25
# Average Score -99.11
# Episode 26
# Average Score -100.13
# Episode 27
# Average Score -100.22
# Episode 28
# Average Score -100.50
# Episode 29
# Average Score -100.58
# Episode 30
# Average Score -100.73
# Episode 31
# Average Score -100.90
# Episode 32
# Average Score -101.10
# Episode 33
# Average Score -101.17
# Episode 34
# Average Score -101.33
# Episode 35
# Average Score -101.48
# Episode 36
# Average Score -101.58
# Episode 37
# Average Score -102.13
# Episode 38
# Average Score -102.97
# Episode 39
# Average Score -103.02
# Episode 40
# Average Score -103.56
# Episode 41
# Average Score -103.73
# Episode 42
# Average Score -103.74
# Episode 43
# Average Score -103.64
# Episode 44
# Average Score -103.96
# Episode 45
# Average Score -104.15
# Episode 46
# Average Score -104.39
# Episode 47
# Average Score -104.59
# Episode 48
# Average Score -104.63
# Episode 49
# Average Score -104.69
# Episode 50
# Average Score -104.90
# Episode 51
# Average Score -104.96
# Episode 52
# Average Score -105.38
# Episode 53
# Average Score -105.60
# Episode 54
# Average Score -105.54
# Episode 55
# Average Score -105.84
# Episode 56
# Average Score -106.21
# Episode 57
# Average Score -106.47
# Episode 58
# Average Score -106.59
# Episode 59
# Average Score -106.78
# Episode 60
# Average Score -106.63
# Episode 61
# Average Score -106.51
# Episode 62
# Average Score -106.42
# Episode 63
# Average Score -106.34
# Episode 64
# Average Score -106.62
# Episode 65
# Average Score -106.14
# Episode 66
# Average Score -106.07
# Episode 67
# Average Score -105.96
# Episode 68
# Average Score -105.49
# Episode 69
# Average Score -105.40
# Episode 70
# Average Score -105.31
# Episode 71
# Average Score -105.23
# Episode 72
# Average Score -105.16
# Episode 73
# Average Score -105.08
# Episode 74
# Average Score -105.33
# Episode 75
# Average Score -105.58
# Episode 76
# Average Score -105.52
# Episode 77
# Average Score -105.60
# Episode 78
# Average Score -105.68
# Episode 79
# Average Score -105.25
# Episode 80
# Average Score -105.42
# Episode 81
# Average Score -105.65
# Episode 82
# Average Score -105.82
# Episode 83
# Average Score -106.06
# Episode 84
# Average Score -106.02
# Episode 85
# Average Score -106.23
# Episode 86
# Average Score -105.67
# Episode 87
# Average Score -105.86
# Episode 88
# Average Score -105.81
# Episode 89
# Average Score -106.05
# Episode 90
# Average Score -105.70
# Episode 91
# Average Score -105.39
# Episode 92
# Average Score -105.62
# Episode 93
# Average Score -105.82
# Episode 94
# Average Score -105.99
# Episode 95
# Average Score -106.14
# Episode 96
# Average Score -106.08
# Episode 97
# Average Score -106.15
# Episode 98
# Average Score -106.11
# Episode 99
# Average Score -106.31
# Episode 100
# Average Score -106.50
# Episode 101
# Average Score -106.71
# Episode 102
# Average Score -106.83
# Episode 103
# Average Score -107.03
# Episode 104
# Average Score -107.32
# Episode 105
# Average Score -107.70
# Episode 106
# Average Score -108.24
# Episode 107
# Average Score -108.12
# Episode 108
# Average Score -108.07
# Episode 109
# Average Score -108.17
# Episode 110
# Average Score -107.69
# Episode 111
# Average Score -107.66
# Episode 112
# Average Score -107.68
# Episode 113
# Average Score -107.64
# Episode 114
# Average Score -107.43
# Episode 115
# Average Score -107.66
# Episode 116
# Average Score -107.77
# Episode 117
# Average Score -107.74
# Episode 118
# Average Score -108.09
# Episode 119
# Average Score -107.95
# Episode 120
# Average Score -108.02
# Episode 121
# Average Score -107.98
# Episode 122
# Average Score -108.16
# Episode 846
# Average Score -80.93
# Episode 847
# Average Score -81.49
# Episode 848
# Average Score -81.50
# Episode 849
# Average Score -81.47
# Episode 850
# Average Score -81.46
# Episode 851
# Average Score -80.98
# Episode 852
# Average Score -81.45
# Episode 853
# Average Score -81.46
# Episode 854
# Average Score -81.72
# Episode 855
# Average Score -82.50
# Episode 856
# Average Score -83.25
# Episode 857
# Average Score -84.00
# Episode 858
# Average Score -84.74
# Episode 859
# Average Score -84.75
# Episode 860
# Average Score -85.00
# Episode 861
# Average Score -85.79
# Episode 862
# Average Score -86.06
# Episode 863
# Average Score -86.32
# Episode 864
# Average Score -87.09
# Episode 865
# Average Score -87.39
# Episode 866
# Average Score -87.43
# Episode 867
# Average Score -87.40
# Episode 868
# Average Score -87.94
# Episode 869
# Average Score -87.95
# Episode 870
# Average Score -88.51
# Episode 871
# Average Score -88.24
# Episode 872
# Average Score -88.59
# Episode 873
# Average Score -88.46
# Episode 874
# Average Score -88.97
# Episode 875
# Average Score -88.21
# Episode 876
# Average Score -88.78
# Episode 877
# Average Score -88.74
# Episode 878
# Average Score -87.97
# Episode 879
# Average Score -87.24
# Episode 880
# Average Score -86.52
# Episode 881
# Average Score -86.26
# Episode 882
# Average Score -86.01
# Episode 883
# Average Score -86.42
# Episode 884
# Average Score -86.40
# Episode 885
# Average Score -86.88
# Episode 886
# Average Score -87.45
# Episode 887
# Average Score -87.45
# Episode 888
# Average Score -86.91
# Episode 889
# Average Score -87.42
# Episode 890
# Average Score -87.92
# Episode 891
# Average Score -88.41
# Episode 892
# Average Score -88.41
# Episode 893
# Average Score -88.43
# Episode 894
# Average Score -89.08
# Episode 895
# Average Score -89.67
# Episode 896
# Average Score -90.43
# Episode 897
# Average Score -91.17
# Episode 898
# Average Score -91.16
# Episode 899
# Average Score -91.71
# Episode 900
# Average Score -91.93
# Episode 901
# Average Score -92.12
# Episode 902
# Average Score -92.24
# Episode 903
# Average Score -92.46
# Episode 904
# Average Score -92.50
# Episode 905
# Average Score -92.56
# Episode 906
# Average Score -92.63
# Episode 907
# Average Score -93.16
# Episode 908
# Average Score -93.16
# Episode 909
# Average Score -93.15
# Episode 910
# Average Score -92.69
# Episode 911
# Average Score -92.70
# Episode 912
# Average Score -93.21
# Episode 913
# Average Score -93.17
# Episode 914
# Average Score -93.00
# Episode 915
# Average Score -92.23
# Episode 916
# Average Score -91.99
# Episode 917
# Average Score -91.73
# Episode 918
# Average Score -91.21
# Episode 919
# Average Score -90.97
# Episode 920
# Average Score -90.77
# Episode 921
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 48
#      45             break
#      46     return scores, losses
# ---> 48 scores, losses = train()
#      49 plot_returns(scores)
#      50 #plot the scores
#
# Cell In[53], line 37, in train(n_episodes, max_t)
#      35     if done:
#      36         break
# ---> 37 loss = agent.learn()
#      38 # For plotting
#      39 losses.append(loss)
#
# Cell In[51], line 108, in Agent.learn(self)
#     102 batch = Experience(*zip(*experiences)) # This converts batch-array of Experiences
#     103                                        # to Experience of batch-arrays.
#     104 #batch.action --> (batch_size, tensor(4,))               ==> (64, tensor(4,))
#     105 #batch.state --> (batch_size, tensor(1,state_size))      ==> (64, tensor(1,24))
#     106 #batch.next_state --> (batch_size, tensor(1,state_size)) ==> (64, tensor(1,24))
#     107 #batch.reward --> (batch_size, tensor(1))                ==> (64, tensor(1))
# --> 108 action_indicies = self.cont2disc(batch.action)
#     109 action_indicies_t = torch.tensor(list(zip(*action_indicies)))   # list(4,64)
#     110 state_batch = torch.cat(batch.state)           # tensor(64, state_size)
#
# Cell In[51], line 90, in Agent.cont2disc(self, action)
#      88 res = [ ]
#      89 for i in range(len(action)):
# ---> 90     res.append(pd.cut(action[i] , bins = np.linspace(-1.0, 1.0, num=21, endpoint = True), labels = np.arange(20), include_lowest=True, right= True))
#      91 return res
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/reshape/tile.py:293, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290     if (np.diff(bins.astype("float64")) < 0).any():
#     291         raise ValueError("bins must increase monotonically.")
# --> 293 fac, bins = _bins_to_cuts(
#     294     x,
#     295     bins,
#     296     right=right,
#     297     labels=labels,
#     298     precision=precision,
#     299     include_lowest=include_lowest,
#     300     dtype=dtype,
#     301     duplicates=duplicates,
#     302     ordered=ordered,
#     303 )
#     305 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/reshape/tile.py:465, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     463     # TODO: handle mismatch between categorical label order and pandas.cut order.
#     464     np.putmask(ids, na_mask, 0)
# --> 465     result = algos.take_nd(labels, ids - 1)
#     467 else:
#     468     result = ids - 1
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/array_algos/take.py:114, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     109         arr = cast("NDArrayBackedExtensionArray", arr)
#     110         return arr.take(
#     111             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     112         )
# --> 114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
#     117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py:163, in NDArrayBackedExtensionArray.take(self, indices, allow_fill, fill_value, axis)
#     154 def take(
#     155     self: NDArrayBackedExtensionArrayT,
#     156     indices: TakeIndexer,
#    (...)
#     160     axis: int = 0,
#     161 ) -> NDArrayBackedExtensionArrayT:
#     162     if allow_fill:
# --> 163         fill_value = self._validate_scalar(fill_value)
#     165     new_data = take(
#     166         self._ndarray,
#     167         indices,
#    (...)
#     170         axis=axis,
#     171     )
#     172     return self._from_backing_data(new_data)
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:1582, in Categorical._validate_scalar(self, fill_value)
#    1564 def _validate_scalar(self, fill_value):
#    1565     """
#    1566     Convert a user-facing fill_value to a representation to use with our
#    1567     underlying ndarray, raising TypeError if this is not possible.
#    (...)
#    1579     TypeError
#    1580     """
# -> 1582     if is_valid_na_for_dtype(fill_value, self.categories.dtype):
#    1583         fill_value = -1
#    1584     elif fill_value in self.categories:
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:712, in is_valid_na_for_dtype(obj, dtype)
#     699 def is_valid_na_for_dtype(obj, dtype: DtypeObj) -> bool:
#     700     """
#     701     isna check that excludes incompatible dtypes
#     702
#    (...)
#     710     bool
#     711     """
# --> 712     if not lib.is_scalar(obj) or not isna(obj):
#     713         return False
#     714     elif dtype.kind == "M":
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:185, in isna(obj)
#     108 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     109     """
#     110     Detect missing values for an array-like object.
#     111
#    (...)
#     183     Name: 1, dtype: bool
#     184     """
# --> 185     return _isna(obj)
#
# File ~/miniconda3/envs/multi_pred/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:191, in _isna(obj, inf_as_na)
#     185     return _isna(obj)
#     188 isnull = isna
# --> 191 def _isna(obj, inf_as_na: bool = False):
#     192     """
#     193     Detect missing values, treating None, NaN or NA as null. Infinite
#     194     values will also be treated as null if inf_as_na is True.
#    (...)
#     205     boolean ndarray or boolean
#     206     """
#     207     if is_scalar(obj):
#
# KeyboardInterrupt:
